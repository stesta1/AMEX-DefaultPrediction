# %%
from sklearn.utils.random import sample_without_replacement
import numpy as np
import pandas as pd

# %%
path_train="path/amex-default-prediction/train_data.csv"
path_label='path/amex-default-prediction/train_labels.csv'

# %%
df_train=pd.read_csv(path_train)
df_labels=pd.read_csv(path_label)

# %%
df_labels.head()
# Out:
#                                          customer_ID  target
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...       0
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...       0
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...       0
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...       0

# %%
df_train.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938469
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936665
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954180
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960384
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947248
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771  0.004709  ...
# 1  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798  0.002714  ...
# 2  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598  0.009423  ...
# 3  0.002455  0.013683  1.002700  0.001373  0.117169  0.000685  0.005531  ...
# 4  0.002483  0.015193  1.000727  0.007605  0.117325  0.004653  0.009312  ...
#
# ...

# %%
numero_grupo=14
random_state=(31416 * numero_grupo) % 1000

# %%
total=df_train.shape[0]#5531451
muestra=np.round(total*5/100)
samples=sample_without_replacement(total,muestra, random_state=random_state)

# %%
df_samples=df_train.iloc[samples]

# %%
df_samples
# Out:
#                                                customer_ID         S_2  \
# 1352172  3e52dec043ba1830f11dec8504f8dad5f4c88e31db5df4...  2018-01-08
# 4921984  e3987751af785c63681334119e0ae8ef61b9195c535fa1...  2018-03-23
# 4378772  ca5cc31bdd33599e7f3e4f0af37bf53c90f441ff9d426e...  2017-09-07
# 2436569  708495d85d01123238b8feea562f321df6306e9d131994...  2017-03-05
# 3084780  8e6325448ec00c432151b1f678db276baa1cf31885faa6...  2017-03-28
# ...                                                    ...         ...
# 3941603  b6259aafe1cbc4057902bfebf7be7fe82110ad1d65c96e...  2018-03-07
# 2990585  8a14e8811699dd4915d710ffbc3c0e81da1b6f36994a63...  2017-06-27
# 4682916  d88b441c8d31ae094880074ad914714fe3dd9836acccbe...  2018-03-23
# 3529666  a31070910c61e92852b56ba61538750021491de5782396...  2017-09-18
# 1623289  4ac96f22ef5f64a403cb7c305b1b99f96023feaee303bf...  2017-11-10
#
#               P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# ...

# %%
df=pd.merge(df_samples,df_labels,on='customer_ID',how='left')

# %%
df.target.value_counts()
# Out:
# 0    207834
# 1     68739
# Name: target, dtype: int64

# %%
#df.reset_index()
df.to_csv("/Users/tomasshiao/Desktop/FIUBA/OrgaDatos/TPs/TP3/amex-default-prediction/train_sampled_grupo14.csv",index=False,header=True)
